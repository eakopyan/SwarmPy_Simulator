# %%
import simpy

# %%
def car(env):
    while True:
        print('Start parking at %d' % env.now)
        parking_duration = 5
        yield env.timeout(parking_duration)
        
        print('Start driving at %d' % env.now)
        trip_duration = 2
        yield env.timeout(trip_duration)

# %%
env = simpy.Environment()
env.process(car(env))
# Out:
# <Process(car) object at 0x14d7e0804f0>

# %%
env.run(until=15)
# Out:
# Start parking at 0
# Start driving at 5
# Start parking at 7
# Start driving at 12
# Start parking at 14

# %%
class Car(object):
    def __init__(self, env):
        self.env = env
        # Start the run process everytime an instance is created.
        self.action = env.process(self.run())

    def run(self):
        while True:
            print('Start parking and charging at %d' % self.env.now)
            charge_duration = 5
            # We may get interrupted while charging the battery
            try:
                yield self.env.process(self.charge(charge_duration))
            except simpy.Interrupt:
                # When we received an interrupt, we stop charging and
                # switch to the "driving" state
                print('Was interrupted. Hope, the battery is full enough ...')

            print('Start driving at %d' % self.env.now)
            trip_duration = 2
            yield self.env.timeout(trip_duration)

    def charge(self, duration):
        yield self.env.timeout(duration)

# %%
def driver(env, car):
    yield env.timeout(3)
    car.action.interrupt()

# %%
env = simpy.Environment()
car = Car(env)
env.process(driver(env, car))
env.run(until=15)
# Out:
# Start parking and charging at 0
# Was interrupted. Hope, the battery is full enough ...
# Start driving at 3
# Start parking and charging at 5
# Start driving at 10
# Start parking and charging at 12

# %%
# Introducing resources

def car(env, name, bcs, driving_time, charge_duration):
    # Simulate driving to the BCS
    yield env.timeout(driving_time)

    # Request one of its charging spots
    print('%s arriving at %d' % (name, env.now))
    with bcs.request() as req:
        yield req

        # Charge the battery
        print('%s starting to charge at %s' % (name, env.now))
        yield env.timeout(charge_duration)
        print('%s leaving the bcs at %s' % (name, env.now))

# %%
env = simpy.Environment()
bcs = simpy.Resource(env, capacity=2)

# %%
for i in range(4):
    env.process(car(env, 'Car %d' % i, bcs, i*2, 5))

# %%
env.run()
# Out:
# Car 0 arriving at 0
# Car 0 starting to charge at 0
# Car 1 arriving at 2
# Car 1 starting to charge at 2
# Car 2 arriving at 4
# Car 0 leaving the bcs at 5
# Car 2 starting to charge at 5
# Car 3 arriving at 6
# Car 1 leaving the bcs at 7
# Car 3 starting to charge at 7
# Car 2 leaving the bcs at 10
# Car 3 leaving the bcs at 12

# %%
import itertools
import random

# %%
RANDOM_SEED = 42
GAS_STATION_SIZE = 200     # liters
THRESHOLD = 10             # Threshold for calling the tank truck (in %)
FUEL_TANK_SIZE = 50        # liters
FUEL_TANK_LEVEL = [5, 25]  # Min/max levels of fuel tanks (in liters)
REFUELING_SPEED = 2        # liters / second
TANK_TRUCK_TIME = 300      # Seconds it takes the tank truck to arrive
T_INTER = [30, 300]        # Create a car every [min, max] seconds
SIM_TIME = 1000            # Simulation time in seconds

# %%
def car(name, env, gas_station, fuel_pump):
    """A car arrives at the gas station for refueling.

    It requests one of the gas station's fuel pumps and tries to get the
    desired amount of gas from it. If the stations reservoir is
    depleted, the car has to wait for the tank truck to arrive.

    """
    fuel_tank_level = random.randint(*FUEL_TANK_LEVEL)
    print('%s arriving at gas station at %.1f' % (name, env.now))
    with gas_station.request() as req:
        start = env.now
        # Request one of the gas pumps
        yield req

        # Get the required amount of fuel
        liters_required = FUEL_TANK_SIZE - fuel_tank_level
        yield fuel_pump.get(liters_required)

        # The "actual" refueling process takes some time
        yield env.timeout(liters_required / REFUELING_SPEED)

        print('%s finished refueling in %.1f seconds.' % (name,
                                                          env.now - start))


def gas_station_control(env, fuel_pump):
    """Periodically check the level of the *fuel_pump* and call the tank
    truck if the level falls below a threshold."""
    while True:
        if fuel_pump.level / fuel_pump.capacity * 100 < THRESHOLD:
            # We need to call the tank truck now!
            print('Calling tank truck at %d' % env.now)
            # Wait for the tank truck to arrive and refuel the station
            yield env.process(tank_truck(env, fuel_pump))

        yield env.timeout(10)  # Check every 10 seconds


def tank_truck(env, fuel_pump):
    """Arrives at the gas station after a certain delay and refuels it."""
    yield env.timeout(TANK_TRUCK_TIME)
    print('Tank truck arriving at time %d' % env.now)
    ammount = fuel_pump.capacity - fuel_pump.level
    print('Tank truck refuelling %.1f liters.' % ammount)
    yield fuel_pump.put(ammount)


def car_generator(env, gas_station, fuel_pump):
    """Generate new cars that arrive at the gas station."""
    for i in itertools.count():
        yield env.timeout(random.randint(*T_INTER))
        env.process(car('Car %d' % i, env, gas_station, fuel_pump))

# %%
# Setup and start the simulation
print('Gas Station refuelling')
random.seed(RANDOM_SEED)

# Create environment and start processes
env = simpy.Environment()
gas_station = simpy.Resource(env, 2)
fuel_pump = simpy.Container(env, GAS_STATION_SIZE, init=GAS_STATION_SIZE)
env.process(gas_station_control(env, fuel_pump))
env.process(car_generator(env, gas_station, fuel_pump))
# Out:
# Gas Station refuelling
# <Process(car_generator) object at 0x14d7e115a30>

# %%
env.run(until=SIM_TIME)
# Out:
# Car 0 arriving at gas station at 87.0
# Car 0 finished refueling in 18.5 seconds.
# Car 1 arriving at gas station at 129.0
# Car 1 finished refueling in 19.0 seconds.
# Car 2 arriving at gas station at 284.0
# Car 2 finished refueling in 21.0 seconds.
# Car 3 arriving at gas station at 385.0
# Car 3 finished refueling in 13.5 seconds.
# Car 4 arriving at gas station at 459.0
# Calling tank truck at 460
# Car 4 finished refueling in 22.0 seconds.
# Car 5 arriving at gas station at 705.0
# Car 6 arriving at gas station at 750.0
# Tank truck arriving at time 760
# Tank truck refuelling 188.0 liters.
# Car 6 finished refueling in 29.0 seconds.
# Car 5 finished refueling in 76.5 seconds.
# Car 7 arriving at gas station at 891.0
# Car 7 finished refueling in 13.0 seconds.

# %% [markdown]
# ## First try on the swarm environment

# %%
import pandas as pd
from tqdm import tqdm
from math import dist

# %%
PATH = '..\data\Traces_Nanosatellites\\track_'
satellites = {}

with tqdm(total=100, desc='Extracting data') as pbar:
    for i in range(0,100):
        df = pd.read_csv(PATH+str(i)+'.csv', sep=',', header=0)
        df['coords'] = ['x','y','z']
        satellites[i] = df.set_index('coords', drop=True)
        pbar.update(1)

satellites[0].head()
# Out:
# Extracting data: 100%|██████████| 100/100 [02:02<00:00,  1.22s/it]
#                    0             1             2             3             4  \
# coords
# x      -4.850747e+05 -4.937755e+05 -5.024536e+05 -5.111086e+05 -5.197401e+05
# y      -7.066530e+05 -7.201117e+05 -7.335372e+05 -7.469290e+05 -7.602864e+05
# z      -2.026363e+06 -2.019625e+06 -2.012795e+06 -2.005871e+06 -1.998855e+06
#
#                    5             6             7             8             9  \
# coords
# x      -5.283476e+05 -5.369309e+05 -5.454894e+05 -5.540229e+05 -5.625310e+05
# y      -7.736088e+05 -7.868957e+05 -8.001464e+05 -8.133603e+05 -8.265368e+05
# z      -1.991747e+06 -1.984548e+06 -1.977257e+06 -1.969876e+06 -1.962403e+06
#
#         ...          9990          9991          9992          9993  \
# coords  ...
# x       ...  1.490967e+06  1.494274e+06  1.497573e+06  1.500865e+06
# y       ...  2.218138e+06  2.223313e+06  2.228477e+06  2.233629e+06
# z       ...  3.692429e+06  3.686602e+06  3.680756e+06  3.674890e+06
#
#                 9994          9995          9996          9997          9998  \
# coords
# x       1.504149e+06  1.507425e+06  1.510693e+06  1.513954e+06  1.517206e+06
# y       2.238769e+06  2.243898e+06  2.249015e+06  2.254120e+06  2.259214e+06
# z       3.669006e+06  3.663103e+06  3.657180e+06  3.651239e+06  3.645278e+06
#
#                 9999
# coords
# x       1.520451e+06
# y       2.264296e+06
# z       3.639299e+06
#
# [3 rows x 10000 columns]

# %%
RANDOM_SEED = 1
NB_NODES = 100
CONNECTION_RANGE = 30000
SIMULATION_TIME = 100

# %%
class Node(object):
    def __init__(self, env, id, x=0.0, y=0.0, z=0.0):
        """
        Node object constructor
        
        Args:
            id (int): the ID number of the satellite (mandatory)
            x (float, optional): the x-coordinate of the satellite. Defaults to 0.
            y (float, optional): the y-coordinate of the satellite. Defaults to 0.
            z (float, optional): the z-coordinate of the satellite. Defaults to 0.
        """
        self.id = int(id)
        self.x = int(x)
        self.y = int(y) 
        self.z = int(z) 
        self.routing_table = [] # List(Node.id), list of neighbor nodes to the node
        self.group = -1 # Group ID to which belongs the node
        self.cache = [] # List(Packet), list of packets that went through
        
        self.env = env
        # Start the run process everytime an instance is created.
        self.action = env.process(self.run())

    def run(self):
        print(f'Created node {self.id} at coordinates ({self.x}, {self.y}, {self.z}).')
        while True:
            print('[%d] Searching for neighbors at %d' % (self.id, self.env.now))
            yield self.env.timeout(1)
            
    def add_neighbor(self, nid):
        if nid not in self.routing_table:
            self.routing_table.append(nid)
    
    def remove_neighbor(self, nid):
        if nid in self.routing_table:
            self.routing_table.remove(nid) 
        
    def compute_dist(self, node):
        return dist((self.x, self.y, self.z) , (node.x, node.y, node.z))
    
    def is_neighbor(self, node, connection_range=CONNECTION_RANGE):
        if node.id != self.id:
            if self.compute_dist(node) <= connection_range:
                self.add_neighbor(node.id)
            else:
                self.remove_neighbor(node.id)
    
    def init_routing_table(self, env, nodes):
        pass

# %%
env = simpy.Environment()
nodes = [Node(env, id, node['0'].x, node['0'].y, node['0'].z) for id,node in satellites.items()]

env.run(until=3)
# Out:
# Created node 0 at coordinates (-485074, -706653, -2026363).
# Start listening at 0
# Created node 1 at coordinates (-416730, -711449, -2013985).
# Start listening at 0
# Created node 2 at coordinates (-483908, -760844, -2023770).
# Start listening at 0
# Created node 3 at coordinates (-352703, -640991, -2034950).
# Start listening at 0
# Created node 4 at coordinates (-457421, -666330, -1985844).
# Start listening at 0
# Created node 5 at coordinates (-454635, -739467, -2018777).
# Start listening at 0
# Created node 6 at coordinates (-423822, -693079, -2033733).
# Start listening at 0
# Created node 7 at coordinates (-463822, -710055, -2004695).
# Start listening at 0
# Created node 8 at coordinates (-417276, -675866, -2007666).
# Start listening at 0
# Created node 9 at coordinates (-450570, -709565, -2007467).
# Start listening at 0
# Created node 10 at coordinates (-460375, -794042, -1977073).
# Start listening at 0
# Created node 11 at coordinates (-458066, -734366, -2024861).
# Start listening at 0
# Created node 12 at coordinates (-441562, -650231, -2050558).
# Start listening at 0
# Created node 13 at coordinates (-510518, -748070, -1976620).
# Start listening at 0
# Created node 14 at coordinates (-434304, -705052, -1980435).
# Start listening at 0
# Created node 15 at coordinates (-402564, -700308, -2019772).
# Start listening at 0
# Created node 16 at coordinates (-489051, -796701, -2014886).
# Start listening at 0
# Created node 17 at coordinates (-449626, -717156, -2007519).
# Start listening at 0
# Created node 18 at coordinates (-421821, -711596, -2030087).
# Start listening at 0
# Created node 19 at coordinates (-469605, -708682, -2024723).
# Start listening at 0
# Created node 20 at coordinates (-436895, -770710, -2008728).
# Start listening at 0
# Created node 21 at coordinates (-456036, -685643, -2053282).
# Start listening at 0
# Created node 22 at coordinates (-436523, -706748, -2034904).
# Start listening at 0
# Created node 23 at coordinates (-431240, -700461, -2051156).
# Start listening at 0
# Created node 24 at coordinates (-458650, -736440, -2020757).
# Start listening at 0
# Created node 25 at coordinates (-498039, -728170, -2000866).
# Start listening at 0
# Created node 26 at coordinates (-392483, -672881, -2042144).
# Start listening at 0
# Created node 27 at coordinates (-440943, -724705, -2024699).
# Start listening at 0
# Created node 28 at coordinates (-444504, -778838, -2002060).
# Start listening at 0
# Created node 29 at coordinates (-448315, -770298, -1999203).
# Start listening at 0
# Created node 30 at coordinates (-427959, -678753, -2024893).
# Start listening at 0
# Created node 31 at coordinates (-468860, -725245, -1976427).
# Start listening at 0
# Created node 32 at coordinates (-441512, -646080, -2028224).
# Start listening at 0
# Created node 33 at coordinates (-448233, -717533, -2027625).
# Start listening at 0
# Created node 34 at coordinates (-383514, -617144, -2050496).
# Start listening at 0
# Created node 35 at coordinates (-462156, -774030, -2002917).
# Start listening at 0
# Created node 36 at coordinates (-465916, -770927, -2045836).
# Start listening at 0
# Created node 37 at coordinates (-430409, -770074, -2069682).
# Start listening at 0
# Created node 38 at coordinates (-449049, -742207, -2058284).
# Start listening at 0
# Created node 39 at coordinates (-428223, -674922, -2045502).
# Start listening at 0
# Created node 40 at coordinates (-454229, -739101, -2027815).
# Start listening at 0
# Created node 41 at coordinates (-464196, -747710, -2025197).
# Start listening at 0
# Created node 42 at coordinates (-450952, -710054, -2020571).
# Start listening at 0
# Created node 43 at coordinates (-401991, -718986, -2047170).
# Start listening at 0
# Created node 44 at coordinates (-462003, -770936, -2014540).
# Start listening at 0
# Created node 45 at coordinates (-424253, -681843, -2020366).
# Start listening at 0
# Created node 46 at coordinates (-475009, -768049, -1973243).
# Start listening at 0
# Created node 47 at coordinates (-439744, -698519, -1960598).
# Start listening at 0
# Created node 48 at coordinates (-470830, -763327, -1989276).
# Start listening at 0
# Created node 49 at coordinates (-468758, -786083, -1987689).
# Start listening at 0
# Created node 50 at coordinates (-459676, -726180, -2029992).
# Start listening at 0
# Created node 51 at coordinates (-486330, -758820, -2001329).
# Start listening at 0
# Created node 52 at coordinates (-460115, -762086, -2002173).
# Start listening at 0
# Created node 53 at coordinates (-479742, -843152, -2013550).
# Start listening at 0
# Created node 54 at coordinates (-549731, -845855, -1951824).
# Start listening at 0
# Created node 55 at coordinates (-466340, -717785, -1994587).
# Start listening at 0
# Created node 56 at coordinates (-424562, -671227, -2056510).
# Start listening at 0
# Created node 57 at coordinates (-458462, -694594, -2011683).
# Start listening at 0
# Created node 58 at coordinates (-473209, -731807, -1981098).
# Start listening at 0
# Created node 59 at coordinates (-469387, -765775, -1966917).
# Start listening at 0
# Created node 60 at coordinates (-412693, -672111, -2021837).
# Start listening at 0
# Created node 61 at coordinates (-469991, -733400, -2071967).
# Start listening at 0
# Created node 62 at coordinates (-427089, -677293, -2053876).
# Start listening at 0
# Created node 63 at coordinates (-454616, -676708, -2007399).
# Start listening at 0
# Created node 64 at coordinates (-493162, -733836, -1992219).
# Start listening at 0
# Created node 65 at coordinates (-437451, -659153, -2041876).
# Start listening at 0
# Created node 66 at coordinates (-434648, -671042, -2026668).
# Start listening at 0
# Created node 67 at coordinates (-452427, -709309, -1990229).
# Start listening at 0
# Created node 68 at coordinates (-425287, -685153, -2031865).
# Start listening at 0
# Created node 69 at coordinates (-418943, -660998, -2066428).
# Start listening at 0
# Created node 70 at coordinates (-453771, -707451, -2026980).
# Start listening at 0
# Created node 71 at coordinates (-445936, -731096, -2021097).
# Start listening at 0
# Created node 72 at coordinates (-428362, -683053, -2011157).
# Start listening at 0
# Created node 73 at coordinates (-457963, -705265, -2010373).
# Start listening at 0
# Created node 74 at coordinates (-411078, -703385, -2017497).
# Start listening at 0
# Created node 75 at coordinates (-460906, -696867, -2019954).
# Start listening at 0
# Created node 76 at coordinates (-417247, -668743, -2052948).
# Start listening at 0
# Created node 77 at coordinates (-440508, -669316, -2036346).
# Start listening at 0
# Created node 78 at coordinates (-451652, -725528, -2010013).
# Start listening at 0
# Created node 79 at coordinates (-477081, -719098, -2051414).
# Start listening at 0
# Created node 80 at coordinates (-472960, -747747, -1998268).
# Start listening at 0
# Created node 81 at coordinates (-486362, -725997, -1982087).
# Start listening at 0
# Created node 82 at coordinates (-521410, -781333, -1981505).
# Start listening at 0
# Created node 83 at coordinates (-494752, -746915, -1954092).
# Start listening at 0
# Created node 84 at coordinates (-443292, -723432, -2003063).
# Start listening at 0
# Created node 85 at coordinates (-474083, -832603, -1981406).
# Start listening at 0
# Created node 86 at coordinates (-342375, -647913, -2068505).
# Start listening at 0
# Created node 87 at coordinates (-446438, -690953, -2037009).
# Start listening at 0
# Created node 88 at coordinates (-513054, -807818, -1963441).
# Start listening at 0
# Created node 89 at coordinates (-493518, -771045, -1968094).
# Start listening at 0
# Created node 90 at coordinates (-442315, -721315, -2027729).
# Start listening at 0
# Created node 91 at coordinates (-509694, -786333, -1966605).
# Start listening at 0
# Created node 92 at coordinates (-511820, -746778, -1944314).
# Start listening at 0
# Created node 93 at coordinates (-411747, -643460, -2026855).
# Start listening at 0
# Created node 94 at coordinates (-474271, -718007, -1990523).
# Start listening at 0
# Created node 95 at coordinates (-483793, -712009, -2036092).
# Start listening at 0
# Created node 96 at coordinates (-439020, -777773, -2014444).
# Start listening at 0
# Created node 97 at coordinates (-460408, -729866, -2005782).
# Start listening at 0
# Created node 98 at coordinates (-491450, -786744, -1986689).
# Start listening at 0
# Created node 99 at coordinates (-449813, -772533, -2044471).
# Start listening at 0
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 1
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
# Start listening at 2
