# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import csv
import pandas as pd

# %matplotlib inline

# %%
df_original = pd.read_csv('..\output\data\sat50_temporal_undivided_weighted_sampled12.csv' , sep=',', index_col='Unnamed: 0')
df_original
# Out:
#      Timestamp  Flow robustness  Redundancy_avg  Disparity_avg    Modularity  \
# 0            0         1.000000        5.651429       0.534890  8.368727e-18
# 1           12         1.000000        6.050612       0.557140 -7.561891e-18
# 2           24         0.921633        5.658990       0.558411  1.847634e-18
# 3           36         0.921633        6.720992       0.570498  4.983973e-18
# 4           48         0.921633        6.860939       0.536964 -5.155834e-19
# ..         ...              ...             ...            ...           ...
# 145       1740         1.000000        7.504490       0.544436  1.925387e-17
# 146       1752         1.000000        6.049796       0.517254  1.017433e-17
# 147       1764         1.000000        5.589388       0.513070  3.267323e-17
# 148       1776         1.000000        5.600000       0.516730  2.530655e-18
# 149       1788         1.000000        5.792653       0.536809 -8.740935e-18
#
#      Criticity  RCost  Efficiency
# 0            5   5514    0.563436
# 1            7   5550    0.560981
# 2            4   5030    0.529101
# 3            6   5082    0.523375
# 4            5   5194    0.519342
# ..         ...    ...         ...
# 145          9   5686    0.554074
# 146          8   5442    0.566218
# 147          5   5536    0.559151
# 148          4   5472    0.566634
# 149          7   5486    0.565491
#
# [150 rows x 8 columns]

# %%
df_mdrw = pd.read_csv('..\output\data\sat50_temporal_weighted_MDRW_sampled12_rep30.csv' , sep=',', index_col='Unnamed: 0')
df_mdrw
# Out:
#       Timestamp  Flow robustness  Redundancy_avg  Disparity_avg  Modularity  \
# 0             0             1.00        6.150000       0.581185   -0.024118
# 1            12             1.00        5.800000       0.543646   -0.022745
# 2            24             0.92        4.434783       0.493548   -0.015117
# 3            36             0.92        8.543478       0.552229   -0.013491
# 4            48             0.92        8.173913       0.501424   -0.013745
# ...         ...              ...             ...            ...         ...
# 4495       1740             1.00        6.000000       0.491931   -0.014140
# 4496       1752             1.00        4.380000       0.440092   -0.007740
# 4497       1764             1.00        3.980000       0.416533   -0.004058
# 4498       1776             1.00        4.190000       0.418974   -0.006246
# 4499       1788             1.00        5.370000       0.495204   -0.019002
#
#       Criticity  RCost  Efficiency
# 0             6    454    0.561167
# 1             6    452    0.561500
# 2             2    404    0.537667
# 3             5    418    0.525667
# 4             6    424    0.530095
# ...         ...    ...         ...
# 4495          6    442    0.583167
# 4496          6    412    0.607000
# 4497          4    416    0.609333
# 4498          3    416    0.611667
# 4499          6    428    0.592000
#
# [4500 rows x 8 columns]

# %%
df_rnd = pd.read_csv('..\output\data\sat50_temporal_weighted_RND_sampled12_rep30.csv' , sep=',', index_col='Unnamed: 0')
df_rnd
# Out:
#       Timestamp  Flow robustness  Redundancy_avg  Disparity_avg    Modularity  \
# 0             0         1.000000        5.651429       0.534890  8.368727e-18
# 1            12         1.000000        6.050612       0.557140 -7.561891e-18
# 2            24         0.921633        5.658990       0.558411  1.847634e-18
# 3            36         0.921633        6.720992       0.570498  4.983973e-18
# 4            48         0.921633        6.860939       0.536964 -5.155834e-19
# ...         ...              ...             ...            ...           ...
# 4495       1740         1.000000        6.863636       0.535788 -1.882062e-02
# 4496       1752         1.000000        6.709091       0.554262 -3.028010e-02
# 4497       1764         1.000000        6.727273       0.523201 -3.132412e-02
# 4498       1776         1.000000        5.509091       0.481109 -2.796713e-02
# 4499       1788         1.000000        4.972727       0.459478 -2.185787e-02
#
#       Criticity  RCost  Efficiency
# 0             5   5514    0.563436
# 1             6   5550    0.560981
# 2             2   5030    0.529101
# 3             5   5082    0.523375
# 4             5   5194    0.519342
# ...         ...    ...         ...
# 4495          8    526    0.546602
# 4496          8    510    0.548182
# 4497          7    516    0.542424
# 4498          7    492    0.562576
# 4499          7    484    0.575455
#
# [4500 rows x 8 columns]

# %%
df_ffd = pd.read_csv('..\output\data\sat50_temporal_weighted_FFD_sampled12_rep30.csv' , sep=',', index_col='Unnamed: 0')
df_ffd
# Out:
#       Timestamp  Flow robustness  Redundancy_avg  Disparity_avg  Modularity  \
# 0             0             1.00        5.490000       0.545853   -0.015432
# 1            12             1.00        4.510000       0.534600   -0.012197
# 2            24             0.92        4.152174       0.550083   -0.009156
# 3            36             0.92        6.532609       0.563756   -0.013486
# 4            48             0.92        8.250000       0.513535   -0.017148
# ...         ...              ...             ...            ...         ...
# 4495       1740             1.00        6.000000       0.491931   -0.014140
# 4496       1752             1.00        4.380000       0.440092   -0.007740
# 4497       1764             1.00        3.980000       0.416533   -0.004058
# 4498       1776             1.00        4.190000       0.418974   -0.006246
# 4499       1788             1.00        5.370000       0.495204   -0.019002
#
#       Criticity  RCost  Efficiency
# 0             4    432    0.583167
# 1             4    426    0.587333
# 2             2    390    0.553000
# 3             2    394    0.540500
# 4             3    398    0.536095
# ...         ...    ...         ...
# 4495          6    442    0.583167
# 4496          6    412    0.607000
# 4497          4    416    0.609333
# 4498          3    416    0.611667
# 4499          6    428    0.592000
#
# [4500 rows x 8 columns]

# %%
mdrw = df_mdrw.groupby('Timestamp').mean()
rnd = df_rnd.groupby('Timestamp').mean()
ffd = df_ffd.groupby('Timestamp').mean()
mdrw
# Out:
#            Flow robustness  Redundancy_avg  Disparity_avg  Modularity  \
# Timestamp
# 0                    1.000        5.706000       0.529262   -0.018223
# 12                   1.000        6.157000       0.548859   -0.017179
# 24                   0.924        5.752660       0.541357   -0.016287
# 36                   0.924        7.007886       0.556861   -0.015226
# 48                   0.924        7.278654       0.524632   -0.016566
# ...                    ...             ...            ...         ...
# 1740                 1.000        7.433667       0.544765   -0.022150
# 1752                 1.000        5.834000       0.501129   -0.019199
# 1764                 1.000        5.289667       0.496228   -0.018991
# 1776                 1.000        5.400333       0.508717   -0.018442
# 1788                 1.000        5.812000       0.532348   -0.018877
#
#            Criticity       RCost  Efficiency
# Timestamp
# 0           5.500000  447.133333    0.572198
# 12          6.233333  449.800000    0.570128
# 24          3.400000  408.866667    0.539696
# 36          4.766667  413.333333    0.534356
# 48          4.633333  422.533333    0.528791
# ...              ...         ...         ...
# 1740        7.633333  461.800000    0.558732
# 1752        6.833333  438.400000    0.575794
# 1764        4.766667  445.733333    0.569565
# 1776        5.266667  442.266667    0.576493
# 1788        5.933333  444.733333    0.573898
#
# [150 rows x 7 columns]

# %%
timestamps = list(rnd.index)
original = df_original.set_index('Timestamp')
original
# Out:
#            Flow robustness  Redundancy_avg  Disparity_avg    Modularity  \
# Timestamp
# 0                 1.000000        5.651429       0.534890  8.368727e-18
# 12                1.000000        6.050612       0.557140 -7.561891e-18
# 24                0.921633        5.658990       0.558411  1.847634e-18
# 36                0.921633        6.720992       0.570498  4.983973e-18
# 48                0.921633        6.860939       0.536964 -5.155834e-19
# ...                    ...             ...            ...           ...
# 1740              1.000000        7.504490       0.544436  1.925387e-17
# 1752              1.000000        6.049796       0.517254  1.017433e-17
# 1764              1.000000        5.589388       0.513070  3.267323e-17
# 1776              1.000000        5.600000       0.516730  2.530655e-18
# 1788              1.000000        5.792653       0.536809 -8.740935e-18
#
#            Criticity  RCost  Efficiency
# Timestamp
# 0                  5   5514    0.563436
# 12                 7   5550    0.560981
# 24                 4   5030    0.529101
# 36                 6   5082    0.523375
# 48                 5   5194    0.519342
# ...              ...    ...         ...
# 1740               9   5686    0.554074
# 1752               8   5442    0.566218
# 1764               5   5536    0.559151
# 1776               4   5472    0.566634
# 1788               7   5486    0.565491
#
# [150 rows x 7 columns]

# %%
import matplotlib.ticker as ticker

def box_plot(datasets, index, fill_color):
    x_pos_range = np.arange(len(datasets)) / (len(datasets) - 1)
    x_pos = (x_pos_range * 0.5) + 0.75
    bp = ax.boxplot(
        np.array(datasets[index]), sym='', whis=[0, 100], widths=0.6 / len(datasets),
        labels=list(datasets[0]),
        positions=[x_pos[index] + j * 1 for j in range(len(datasets[index].T))],
        patch_artist=True
    )
    for patch in bp['boxes']:
        patch.set(facecolor=fill_color)       
    return bp

# %%
range_low = (828-5*12, 828+5*12)
range_avg = (252-5*12, 252+5*12) 
range_high = (1788-10*12,1788)

# %%
metric = 'Criticity'

data_original = pd.DataFrame({
    'Low': original[metric].loc[original.index.isin(range_low)].tolist(),
    'Average': original[metric].loc[original.index.isin(range_avg)].tolist(),
    'High': original[metric].loc[original.index.isin(range_high)].tolist()
})

data_mdrw = pd.DataFrame({
    'Low': mdrw[metric].loc[mdrw.index.isin(range_low)].tolist(),
    'Average': mdrw[metric].loc[mdrw.index.isin(range_avg)].tolist(),
    'High': mdrw[metric].loc[mdrw.index.isin(range_high)].tolist()
})

data_rnd = pd.DataFrame({
    'Low': rnd[metric].loc[rnd.index.isin(range_low)].tolist(),
    'Average': rnd[metric].loc[rnd.index.isin(range_avg)].tolist(),
    'High': rnd[metric].loc[rnd.index.isin(range_high)].tolist()
})

data_ffd = pd.DataFrame({
    'Low': ffd[metric].loc[ffd.index.isin(range_low)].tolist(),
    'Average': ffd[metric].loc[ffd.index.isin(range_avg)].tolist(),
    'High': ffd[metric].loc[ffd.index.isin(range_high)].tolist()
})

datasets = [data_original, data_mdrw, data_rnd, data_ffd]

# %%
fig, ax = plt.subplots(figsize=(6,6))
bp0 = box_plot(datasets, 0, 'lightgray')
bp1 = box_plot(datasets, 1, 'lightblue')
bp2 = box_plot(datasets, 2, 'orange')
bp3 = box_plot(datasets, 3, 'lightgreen')

plt.xticks(np.arange(len(list(datasets[0]))) + 1)
plt.gca().xaxis.set_minor_locator(ticker.FixedLocator(
    np.array(range(len(list(datasets[0])) + 1)) + 0.5)
)
plt.gca().tick_params(axis='x', which='minor', length=4)
plt.gca().tick_params(axis='x', which='major', length=0)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.legend([bp0["boxes"][0], bp1["boxes"][0], bp2["boxes"][0], bp3["boxes"][0]], ['Original', 'MIRW', 'RND', 'FFD'])
ax.set_ylim(0,20)
ax.set_ylabel('# Critical nodes')
# Out:
# Text(0, 0.5, '# Critical nodes')

# %%
fig,ax = plt.subplots(figsize=(6,6))
idx = np.linspace(0,1800, 150)
metric = 'Criticity'

ax.plot(idx, original[metric], label='Original', c='darkgray')
ax.plot(idx, mdrw[metric], label='MIRW')
ax.plot(idx, rnd[metric], label='RND')
ax.plot(idx, ffd[metric], label='FFD')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.legend()
ax.set_xlabel('Timestamp')
#ax.set_ylabel('Flow robustness')
ax.set_xlim(0,1800)
ax.set_ylim(0,25)
# Out:
# (0.0, 25.0)

# %%
fig, ax = plt.subplots(figsize=(6,6))
idx = list(original.index)
metric = 'RCost'

ax.plot(idx, original[metric], label='Original', c='darkgray')
ax.set_xlabel('Timestamp')
ax.set_ylabel('Routing cost (original)', color='darkgray')
ax.tick_params(axis='y', labelcolor='darkgray')
ax.set_xlim(0,1800)
ax.set_ylim(3000, 19000)
#ax.legend()

ax2 = ax.twinx()
ax2.plot(idx, mdrw[metric], label='MIRW')
ax2.plot(idx, rnd[metric], label='RND')
ax2.plot(idx, ffd[metric], label='FFD')
ax2.set_ylabel('Routing cost (divided)', color='black')
ax2.set_ylim(0, 3000)
ax2.tick_params(axis='y', labelcolor='black')
ax2.legend()

fig.tight_layout()

# %%
def packet_ratio(df):
    rc = df['RCost'].tolist()
    coef = df['Flow robustness'].tolist()
    return [n/m for n,m in zip(rc, coef)]

# %%
fig, ax = plt.subplots(figsize=(6,6))
idx = list(original.index)

ax.plot(idx, packet_ratio(original), label='Original', c='darkgray')
ax.set_xlabel('Timestamp')
ax.set_ylabel('Packet ratio (original)', color='darkgray')
ax.tick_params(axis='y', labelcolor='darkgray')
ax.set_xlim(0,1800)
ax.set_ylim(2000, 21000)
#ax.legend()

ax2 = ax.twinx()
ax2.plot(idx, packet_ratio(mdrw), label='MIRW')
ax2.plot(idx, packet_ratio(rnd), label='RND')
ax2.plot(idx, packet_ratio(ffd), label='FFD')
ax2.set_ylabel('Packet ratio (divided)', color='black')
ax2.set_ylim(0, 3000)
ax2.tick_params(axis='y', labelcolor='black')
ax2.legend(loc='upper left')

fig.tight_layout()

# %% [markdown]
# ## Correlation analysis

# %%
variables = ['Redundancy_avg', 'Flow robustness', 'Disparity_avg', 'Modularity', 'Criticity', 'RCost', 'Efficiency']

# %%
df_original = df_original.set_index('Timestamp')
df_original.head()
# Out:
#            Flow robustness  Redundancy_avg  Disparity_avg    Modularity  \
# Timestamp
# 0                 1.000000        5.651429       0.534890  8.368727e-18
# 12                1.000000        6.050612       0.557140 -7.561891e-18
# 24                0.921633        5.658990       0.558411  1.847634e-18
# 36                0.921633        6.720992       0.570498  4.983973e-18
# 48                0.921633        6.860939       0.536964 -5.155834e-19
#
#            Criticity  RCost  Efficiency
# Timestamp
# 0                  5   5514    0.563436
# 12                 7   5550    0.560981
# 24                 4   5030    0.529101
# 36                 6   5082    0.523375
# 48                 5   5194    0.519342

# %%
df_mdrw = df_mdrw.set_index('Timestamp')
df_mdrw.head()
# Out:
#            Flow robustness  Redundancy_avg  Disparity_avg  Modularity  \
# Timestamp
# 0                     1.00        6.150000       0.581185   -0.024118
# 12                    1.00        5.800000       0.543646   -0.022745
# 24                    0.92        4.434783       0.493548   -0.015117
# 36                    0.92        8.543478       0.552229   -0.013491
# 48                    0.92        8.173913       0.501424   -0.013745
#
#            Criticity  RCost  Efficiency
# Timestamp
# 0                  6    454    0.561167
# 12                 6    452    0.561500
# 24                 2    404    0.537667
# 36                 5    418    0.525667
# 48                 6    424    0.530095

# %%
df_original.corr()
# Out:
#                  Flow robustness  Redundancy_avg  Disparity_avg  Modularity  \
# Flow robustness         1.000000        0.136255       0.227320    0.032083
# Redundancy_avg          0.136255        1.000000       0.782365   -0.020428
# Disparity_avg           0.227320        0.782365       1.000000    0.012958
# Modularity              0.032083       -0.020428       0.012958    1.000000
# Criticity              -0.005231       -0.379919      -0.500230    0.082497
# RCost                   0.354542       -0.518819      -0.626378   -0.008958
# Efficiency              0.385703        0.669104       0.855028    0.003917
#
#                  Criticity     RCost  Efficiency
# Flow robustness  -0.005231  0.354542    0.385703
# Redundancy_avg   -0.379919 -0.518819    0.669104
# Disparity_avg    -0.500230 -0.626378    0.855028
# Modularity        0.082497 -0.008958    0.003917
# Criticity         1.000000  0.665550   -0.682216
# RCost             0.665550  1.000000   -0.685514
# Efficiency       -0.682216 -0.685514    1.000000

# %%
df_mdrw.corr()
# Out:
#                  Flow robustness  Redundancy_avg  Disparity_avg  Modularity  \
# Flow robustness         1.000000        0.132180       0.197760    0.031547
# Redundancy_avg          0.132180        1.000000       0.710048   -0.145137
# Disparity_avg           0.197760        0.710048       1.000000   -0.311521
# Modularity              0.031547       -0.145137      -0.311521    1.000000
# Criticity              -0.004815       -0.333338      -0.426715   -0.049825
# RCost                   0.350888       -0.469903      -0.543960    0.037811
# Efficiency              0.387736        0.590871       0.705279    0.090212
#
#                  Criticity     RCost  Efficiency
# Flow robustness  -0.004815  0.350888    0.387736
# Redundancy_avg   -0.333338 -0.469903    0.590871
# Disparity_avg    -0.426715 -0.543960    0.705279
# Modularity       -0.049825  0.037811    0.090212
# Criticity         1.000000  0.660620   -0.691488
# RCost             0.660620  1.000000   -0.672658
# Efficiency       -0.691488 -0.672658    1.000000
